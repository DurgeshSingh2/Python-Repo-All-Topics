# %%
##print functionality

# %%
a = 5
print('hello' ,        'world',a)
# Out:
# hello world 5

# %%
print('hello','world')
print('Hello World')
a = 'hello'
b = 'world'
# Out:
# hello world
# Hello World

# %%
print(a+   b, end=' ')
print(a+' '+b)
print(b)
a = 5
b = 2
print(a+b)
print(5+2)
# Out:
# helloworld hello world
# world
# 7
# 7

# %%
time(print('hello','world',end=" ")
print('Hello World',end="")
a = 'hello'
b = 'world'
print(a+b,end=" ")
print(a+' '+b,end=""))
# Out:
#   File "<ipython-input-44-59e8a13a84e9>", line 2
#     print('Hello World',end="")
#         ^
# SyntaxError: invalid syntax

# %%
## numeric operations 
## operators
## /    : Division
## *    : Multiplication
## +    : addition
## -    : subtraction
## %    : modulus (remainder)
## //   : Floor value
## **   : exponentiation (raised to the power)

# %%
5/2
# Out:
# 2.5

# %%
321//10
# Out:
# 32

# %%
32//10
# Out:
# 3

# %%
2**2
# Out:
# 4

# %%
4**2
# Out:
# 16

# %%
2**3
# Out:
# 8

# %%
a = 5
print(type(a))
# Out:
# <class 'int'>

# %%
b = 2
print(type(b))
# Out:
# <class 'float'>

# %%
print(int(a/b))
# Out:
# 2

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-441b0976867a> in <module>
#       1 c= 0
#       2 i = 1
# ----> 3 while i>0:
#       4   c = c+1
#
# KeyboardInterrupt:
